# %% [markdown]
# <a href="https://colab.research.google.com/github/naimahsesay08-dot/Emmy-Award-Project-/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/frontiertechinstitute/datasets.git
df = pd.read_csv('datasets/emmy_cleaned.csv')
df.head(10)
# Out:
# fatal: destination path 'datasets' already exists and is not an empty directory.
#                                             category  \
# 0  Outstanding Character Voice-Over Performance -...
# 1  Outstanding Character Voice-Over Performance -...
# 2  Outstanding Character Voice-Over Performance -...
# 3  Outstanding Character Voice-Over Performance -...
# 4  Outstanding Production Design For A Narrative ...
# 5  Outstanding Production Design For A Narrative ...
# 6  Outstanding Production Design For A Narrative ...
# 7  Outstanding Production Design For A Narrative ...
# 8  Outstanding Production Design For A Narrative ...
# 9  Outstanding Production Design For A Narrative ...
#
#                                 production     type  \
# 0                                      NaN  Nominee
# 1                                      NaN  Nominee
# 2                                      NaN  Nominee
# 3                                      NaN  Nominee
# ...
